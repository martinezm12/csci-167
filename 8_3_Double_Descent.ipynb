# %% [markdown]
# <a href="https://colab.research.google.com/github/martinezm12/csci-167/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-4e3rkz5l
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-4e3rkz5l
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1419941af633931cc2bfd29b77642333b3b5e1d08a9d032da97ba19ef6d46870
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aspxyps2/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# 1. around 4000 units
# 2. around 500 units
# 3. around 4000 - 6000 units

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301729, train error 89.22,  test loss 2.303279, test error 89.80
# Epoch   100, train loss 1.918455, train error 71.30,  test loss 1.777108, test error 69.10
# Epoch   200, train loss 1.898162, train error 71.20,  test loss 1.745901, test error 69.32
# Epoch   300, train loss 1.893486, train error 70.22,  test loss 1.741480, test error 69.62
# Epoch   400, train loss 1.891373, train error 70.95,  test loss 1.730357, test error 69.47
# Epoch   500, train loss 1.890825, train error 70.97,  test loss 1.738300, test error 70.22
# Epoch   600, train loss 1.889959, train error 70.72,  test loss 1.732927, test error 68.88
# Epoch   700, train loss 1.889830, train error 70.03,  test loss 1.730918, test error 68.55
# Epoch   800, train loss 1.890440, train error 70.82,  test loss 1.734775, test error 70.28
# Epoch   900, train loss 1.893872, train error 71.40,  test loss 1.721561, test error 69.35
# Training model with   4 hidden variables
# Epoch     0, train loss 2.232869, train error 81.38,  test loss 2.214255, test error 80.72
# Epoch   100, train loss 1.786077, train error 66.57,  test loss 1.594947, test error 62.15
# Epoch   200, train loss 1.774966, train error 65.70,  test loss 1.578729, test error 62.03
# Epoch   300, train loss 1.745638, train error 62.75,  test loss 1.530834, test error 59.15
# Epoch   400, train loss 1.737225, train error 61.62,  test loss 1.527992, test error 57.50
# Epoch   500, train loss 1.737285, train error 62.42,  test loss 1.530837, test error 58.65
# Epoch   600, train loss 1.737959, train error 62.08,  test loss 1.540822, test error 60.08
# Epoch   700, train loss 1.735814, train error 62.47,  test loss 1.530778, test error 59.33
# Epoch   800, train loss 1.730473, train error 62.70,  test loss 1.522682, test error 59.53
# Epoch   900, train loss 1.739342, train error 63.55,  test loss 1.533896, test error 59.80
# Training model with   6 hidden variables
# Epoch     0, train loss 2.302722, train error 87.38,  test loss 2.305429, test error 87.47
# Epoch   100, train loss 1.662657, train error 59.12,  test loss 1.478509, test error 57.35
# Epoch   200, train loss 1.605191, train error 56.42,  test loss 1.427296, test error 53.55
# Epoch   300, train loss 1.592050, train error 55.85,  test loss 1.434201, test error 53.58
# Epoch   400, train loss 1.583189, train error 55.22,  test loss 1.425199, test error 53.00
# Epoch   500, train loss 1.580000, train error 55.35,  test loss 1.413984, test error 53.12
# Epoch   600, train loss 1.572753, train error 54.67,  test loss 1.420761, test error 52.88
# Epoch   700, train loss 1.551211, train error 53.55,  test loss 1.397878, test error 52.62
# Epoch   800, train loss 1.545666, train error 53.75,  test loss 1.390797, test error 52.03
# Epoch   900, train loss 1.546749, train error 53.58,  test loss 1.398316, test error 53.12
# Training model with   8 hidden variables
# Epoch     0, train loss 2.232173, train error 83.57,  test loss 2.218809, test error 83.18
# Epoch   100, train loss 1.585992, train error 56.03,  test loss 1.442305, test error 55.22
# Epoch   200, train loss 1.548361, train error 53.95,  test loss 1.391631, test error 53.05
# Epoch   300, train loss 1.533390, train error 53.00,  test loss 1.378624, test error 51.80
# Epoch   400, train loss 1.527136, train error 53.17,  test loss 1.391397, test error 53.22
# Epoch   500, train loss 1.517033, train error 52.47,  test loss 1.385693, test error 53.03
# Epoch   600, train loss 1.520763, train error 52.45,  test loss 1.395458, test error 52.80
# Epoch   700, train loss 1.505248, train error 52.17,  test loss 1.411450, test error 53.17
# Epoch   800, train loss 1.500159, train error 52.40,  test loss 1.403383, test error 53.33
# Epoch   900, train loss 1.496724, train error 52.67,  test loss 1.402543, test error 52.75
# Training model with  10 hidden variables
# Epoch     0, train loss 2.290733, train error 87.03,  test loss 2.304053, test error 87.43
# Epoch   100, train loss 1.529735, train error 53.17,  test loss 1.382075, test error 52.20
# Epoch   200, train loss 1.445597, train error 49.12,  test loss 1.309774, test error 48.75
# Epoch   300, train loss 1.421306, train error 48.25,  test loss 1.302082, test error 48.45
# Epoch   400, train loss 1.410430, train error 47.50,  test loss 1.292685, test error 48.33
# Epoch   500, train loss 1.404369, train error 47.62,  test loss 1.295913, test error 48.10
# Epoch   600, train loss 1.407842, train error 48.10,  test loss 1.298911, test error 48.72
# Epoch   700, train loss 1.398292, train error 47.60,  test loss 1.302136, test error 48.25
# Epoch   800, train loss 1.400200, train error 47.72,  test loss 1.302574, test error 48.17
# Epoch   900, train loss 1.394405, train error 47.47,  test loss 1.303206, test error 48.30
# Training model with  14 hidden variables
# Epoch     0, train loss 2.248781, train error 84.57,  test loss 2.228921, test error 85.65
# Epoch   100, train loss 1.404439, train error 47.38,  test loss 1.294064, test error 47.40
# Epoch   200, train loss 1.338010, train error 45.55,  test loss 1.313832, test error 48.62
# Epoch   300, train loss 1.307173, train error 44.58,  test loss 1.330315, test error 48.45
# Epoch   400, train loss 1.299769, train error 44.47,  test loss 1.350805, test error 48.78
# Epoch   500, train loss 1.271069, train error 43.45,  test loss 1.369271, test error 48.55
# Epoch   600, train loss 1.260716, train error 43.03,  test loss 1.369784, test error 48.55
# Epoch   700, train loss 1.257807, train error 42.90,  test loss 1.385483, test error 48.83
# Epoch   800, train loss 1.251324, train error 43.17,  test loss 1.396488, test error 48.92
# Epoch   900, train loss 1.246408, train error 43.08,  test loss 1.422787, test error 49.35
# Training model with  18 hidden variables
# Epoch     0, train loss 2.223489, train error 82.07,  test loss 2.202668, test error 82.10
# Epoch   100, train loss 1.370492, train error 45.67,  test loss 1.379430, test error 51.58
# Epoch   200, train loss 1.281327, train error 42.28,  test loss 1.385567, test error 50.15
# Epoch   300, train loss 1.233474, train error 41.05,  test loss 1.409176, test error 50.30
# Epoch   400, train loss 1.201431, train error 39.75,  test loss 1.433385, test error 50.05
# Epoch   500, train loss 1.176674, train error 39.60,  test loss 1.477035, test error 50.62
# Epoch   600, train loss 1.165705, train error 38.45,  test loss 1.526888, test error 50.47
# Epoch   700, train loss 1.144577, train error 38.47,  test loss 1.572858, test error 50.20
# Epoch   800, train loss 1.139559, train error 38.47,  test loss 1.601478, test error 50.53
# Epoch   900, train loss 1.135355, train error 38.42,  test loss 1.608072, test error 50.47
# Training model with  22 hidden variables
# Epoch     0, train loss 2.207903, train error 81.68,  test loss 2.204916, test error 81.75
# Epoch   100, train loss 1.281599, train error 42.45,  test loss 1.379505, test error 51.62
# Epoch   200, train loss 1.155267, train error 38.88,  test loss 1.423570, test error 51.78
# Epoch   300, train loss 1.094016, train error 35.93,  test loss 1.481591, test error 51.75
# Epoch   400, train loss 1.060619, train error 35.20,  test loss 1.558546, test error 53.12
# Epoch   500, train loss 1.041696, train error 35.28,  test loss 1.616813, test error 53.75
# Epoch   600, train loss 1.028944, train error 35.38,  test loss 1.644021, test error 53.35
# Epoch   700, train loss 1.010216, train error 34.43,  test loss 1.683219, test error 54.03
# Epoch   800, train loss 1.005935, train error 34.30,  test loss 1.714543, test error 54.72
# Epoch   900, train loss 0.991611, train error 33.25,  test loss 1.767896, test error 55.45
# Training model with  26 hidden variables
# Epoch     0, train loss 2.121364, train error 79.30,  test loss 2.061237, test error 77.18
# Epoch   100, train loss 1.176523, train error 38.30,  test loss 1.269679, test error 47.42
# Epoch   200, train loss 1.051980, train error 34.30,  test loss 1.388983, test error 49.00
# Epoch   300, train loss 0.998231, train error 32.53,  test loss 1.521919, test error 50.38
# Epoch   400, train loss 0.939568, train error 30.82,  test loss 1.610598, test error 50.92
# Epoch   500, train loss 0.917136, train error 30.82,  test loss 1.755146, test error 51.70
# Epoch   600, train loss 0.885718, train error 29.62,  test loss 1.835705, test error 51.95
# Epoch   700, train loss 0.859572, train error 28.20,  test loss 1.928093, test error 52.65
# Epoch   800, train loss 0.843076, train error 28.72,  test loss 1.969089, test error 53.17
# Epoch   900, train loss 0.835645, train error 28.25,  test loss 2.057336, test error 53.70
# Training model with  30 hidden variables
# Epoch     0, train loss 2.114359, train error 79.88,  test loss 2.061434, test error 78.85
# Epoch   100, train loss 1.077100, train error 35.78,  test loss 1.303541, test error 47.10
# Epoch   200, train loss 0.892310, train error 29.07,  test loss 1.439454, test error 47.22
# Epoch   300, train loss 0.840379, train error 28.43,  test loss 1.655763, test error 49.33
# Epoch   400, train loss 0.774800, train error 25.78,  test loss 1.772707, test error 48.95
# Epoch   500, train loss 0.744917, train error 24.65,  test loss 1.933614, test error 50.80
# Epoch   600, train loss 0.713223, train error 23.43,  test loss 2.040922, test error 51.10
# Epoch   700, train loss 0.709462, train error 23.75,  test loss 2.138635, test error 51.40
# Epoch   800, train loss 0.682409, train error 23.50,  test loss 2.287502, test error 53.38
# Epoch   900, train loss 0.657663, train error 22.18,  test loss 2.347332, test error 53.33
# Training model with  35 hidden variables
# Epoch     0, train loss 2.123453, train error 78.12,  test loss 2.071783, test error 78.40
# Epoch   100, train loss 1.017364, train error 32.75,  test loss 1.357620, test error 48.10
# Epoch   200, train loss 0.810891, train error 26.30,  test loss 1.628095, test error 50.20
# Epoch   300, train loss 0.696854, train error 22.85,  test loss 1.950919, test error 51.47
# Epoch   400, train loss 0.618242, train error 20.45,  test loss 2.289373, test error 53.08
# Epoch   500, train loss 0.559342, train error 19.00,  test loss 2.676817, test error 53.10
# Epoch   600, train loss 0.514264, train error 17.93,  test loss 2.942135, test error 54.58
# Epoch   700, train loss 0.493139, train error 16.93,  test loss 3.251481, test error 55.60
# Epoch   800, train loss 0.499393, train error 17.68,  test loss 3.505124, test error 55.22
# Epoch   900, train loss 0.452109, train error 15.75,  test loss 3.821401, test error 55.92
# Training model with  40 hidden variables
# Epoch     0, train loss 2.115063, train error 79.22,  test loss 2.054353, test error 78.75
# Epoch   100, train loss 0.948505, train error 30.75,  test loss 1.443504, test error 50.90
# Epoch   200, train loss 0.687096, train error 22.62,  test loss 1.877624, test error 52.47
# Epoch   300, train loss 0.529670, train error 16.88,  test loss 2.390920, test error 53.75
# Epoch   400, train loss 0.470952, train error 16.47,  test loss 2.945734, test error 53.62
# Epoch   500, train loss 0.381763, train error 12.60,  test loss 3.517303, test error 55.12
# Epoch   600, train loss 0.368573, train error 12.47,  test loss 4.028547, test error 54.22
# Epoch   700, train loss 0.342740, train error 12.05,  test loss 4.712176, test error 54.95
# Epoch   800, train loss 0.344211, train error 11.75,  test loss 5.275191, test error 55.75
# Epoch   900, train loss 0.343050, train error 12.03,  test loss 5.871948, test error 55.90
# Training model with  45 hidden variables
# Epoch     0, train loss 2.083982, train error 76.75,  test loss 2.040629, test error 76.85
# Epoch   100, train loss 0.801167, train error 25.90,  test loss 1.478820, test error 49.80
# Epoch   200, train loss 0.500154, train error 16.20,  test loss 2.224108, test error 53.50
# Epoch   300, train loss 0.322734, train error 10.70,  test loss 3.284862, test error 54.75
# Epoch   400, train loss 0.238624, train error 8.68,  test loss 4.503004, test error 55.97
# Epoch   500, train loss 0.126694, train error 3.97,  test loss 5.690191, test error 56.42
# Epoch   600, train loss 0.158130, train error 5.28,  test loss 6.644046, test error 55.22
# Epoch   700, train loss 0.197536, train error 7.22,  test loss 7.631049, test error 55.83
# Epoch   800, train loss 0.010335, train error 0.00,  test loss 8.548429, test error 56.03
# Epoch   900, train loss 0.005459, train error 0.00,  test loss 9.170712, test error 56.00
# Training model with  50 hidden variables
# Epoch     0, train loss 2.146425, train error 80.95,  test loss 2.118027, test error 80.93
# Epoch   100, train loss 0.728208, train error 23.07,  test loss 1.630165, test error 51.92
# Epoch   200, train loss 0.349285, train error 10.22,  test loss 2.648408, test error 53.05
# Epoch   300, train loss 0.162310, train error 3.90,  test loss 4.264055, test error 54.85
# Epoch   400, train loss 0.032403, train error 0.05,  test loss 5.907401, test error 56.83
# Epoch   500, train loss 0.014528, train error 0.00,  test loss 6.957325, test error 56.70
# Epoch   600, train loss 0.008753, train error 0.00,  test loss 7.622315, test error 57.05
# Epoch   700, train loss 0.006222, train error 0.00,  test loss 8.117008, test error 57.25
# Epoch   800, train loss 0.004810, train error 0.00,  test loss 8.512038, test error 57.33
# Epoch   900, train loss 0.003858, train error 0.00,  test loss 8.837829, test error 57.40
# Training model with  55 hidden variables
# Epoch     0, train loss 2.052615, train error 77.15,  test loss 1.991322, test error 76.25
# Epoch   100, train loss 0.616179, train error 18.35,  test loss 1.637482, test error 50.40
# Epoch   200, train loss 0.217814, train error 5.88,  test loss 3.056414, test error 54.08
# Epoch   300, train loss 0.039691, train error 0.03,  test loss 4.811497, test error 55.10
# Epoch   400, train loss 0.014212, train error 0.00,  test loss 5.834022, test error 55.00
# Epoch   500, train loss 0.008164, train error 0.00,  test loss 6.453951, test error 54.95
# Epoch   600, train loss 0.005647, train error 0.00,  test loss 6.907284, test error 55.12
# Epoch   700, train loss 0.004238, train error 0.00,  test loss 7.259395, test error 55.15
# Epoch   800, train loss 0.003369, train error 0.00,  test loss 7.546292, test error 55.05
# Epoch   900, train loss 0.002781, train error 0.00,  test loss 7.784376, test error 55.10
# Training model with  60 hidden variables
# Epoch     0, train loss 2.054774, train error 76.18,  test loss 2.011009, test error 75.62
# Epoch   100, train loss 0.529809, train error 15.12,  test loss 1.731644, test error 51.40
# Epoch   200, train loss 0.090250, train error 0.53,  test loss 3.457764, test error 55.12
# Epoch   300, train loss 0.019032, train error 0.00,  test loss 4.776355, test error 55.53
# Epoch   400, train loss 0.009022, train error 0.00,  test loss 5.450222, test error 55.22
# Epoch   500, train loss 0.005764, train error 0.00,  test loss 5.896716, test error 55.50
# Epoch   600, train loss 0.004138, train error 0.00,  test loss 6.231566, test error 55.55
# Epoch   700, train loss 0.003198, train error 0.00,  test loss 6.494419, test error 55.75
# Epoch   800, train loss 0.002584, train error 0.00,  test loss 6.717284, test error 55.75
# Epoch   900, train loss 0.002155, train error 0.00,  test loss 6.902350, test error 55.72
# Training model with  70 hidden variables
# Epoch     0, train loss 2.035794, train error 74.82,  test loss 1.988427, test error 75.22
# Epoch   100, train loss 0.334566, train error 7.82,  test loss 2.008984, test error 53.00
# Epoch   200, train loss 0.032546, train error 0.00,  test loss 3.686647, test error 54.58
# Epoch   300, train loss 0.010923, train error 0.00,  test loss 4.491834, test error 54.97
# Epoch   400, train loss 0.006104, train error 0.00,  test loss 4.951581, test error 55.15
# Epoch   500, train loss 0.004140, train error 0.00,  test loss 5.277846, test error 55.35
# Epoch   600, train loss 0.003049, train error 0.00,  test loss 5.514205, test error 55.42
# Epoch   700, train loss 0.002397, train error 0.00,  test loss 5.714964, test error 55.55
# Epoch   800, train loss 0.001956, train error 0.00,  test loss 5.877650, test error 55.55
# Epoch   900, train loss 0.001643, train error 0.00,  test loss 6.018865, test error 55.55
# Training model with  80 hidden variables
# Epoch     0, train loss 2.016437, train error 74.38,  test loss 1.964273, test error 74.50
# Epoch   100, train loss 0.220952, train error 3.75,  test loss 2.171093, test error 53.15
# Epoch   200, train loss 0.019392, train error 0.00,  test loss 3.538768, test error 51.85
# Epoch   300, train loss 0.007951, train error 0.00,  test loss 4.112711, test error 52.25
# Epoch   400, train loss 0.004732, train error 0.00,  test loss 4.456311, test error 52.55
# Epoch   500, train loss 0.003280, train error 0.00,  test loss 4.699686, test error 52.78
# Epoch   600, train loss 0.002480, train error 0.00,  test loss 4.888751, test error 52.85
# Epoch   700, train loss 0.001970, train error 0.00,  test loss 5.041519, test error 52.83
# Epoch   800, train loss 0.001624, train error 0.00,  test loss 5.171109, test error 52.78
# Epoch   900, train loss 0.001375, train error 0.00,  test loss 5.282984, test error 52.90
# Training model with  90 hidden variables
# Epoch     0, train loss 2.013733, train error 74.03,  test loss 1.955886, test error 73.35
# Epoch   100, train loss 0.144552, train error 1.20,  test loss 2.159698, test error 49.70
# Epoch   200, train loss 0.014689, train error 0.00,  test loss 3.235338, test error 50.03
# Epoch   300, train loss 0.006459, train error 0.00,  test loss 3.670598, test error 50.42
# Epoch   400, train loss 0.003936, train error 0.00,  test loss 3.931997, test error 50.40
# Epoch   500, train loss 0.002768, train error 0.00,  test loss 4.120811, test error 50.45
# Epoch   600, train loss 0.002104, train error 0.00,  test loss 4.268455, test error 50.50
# Epoch   700, train loss 0.001683, train error 0.00,  test loss 4.389349, test error 50.45
# Epoch   800, train loss 0.001393, train error 0.00,  test loss 4.491756, test error 50.53
# Epoch   900, train loss 0.001183, train error 0.00,  test loss 4.578682, test error 50.58
# Training model with 100 hidden variables
# Epoch     0, train loss 1.981318, train error 73.22,  test loss 1.920437, test error 73.55
# Epoch   100, train loss 0.084846, train error 0.12,  test loss 2.304116, test error 51.25
# Epoch   200, train loss 0.011853, train error 0.00,  test loss 3.190202, test error 52.15
# Epoch   300, train loss 0.005563, train error 0.00,  test loss 3.562073, test error 52.35
# Epoch   400, train loss 0.003469, train error 0.00,  test loss 3.794359, test error 52.15
# Epoch   500, train loss 0.002473, train error 0.00,  test loss 3.964458, test error 52.17
# Epoch   600, train loss 0.001896, train error 0.00,  test loss 4.098531, test error 52.15
# Epoch   700, train loss 0.001524, train error 0.00,  test loss 4.209941, test error 52.25
# Epoch   800, train loss 0.001266, train error 0.00,  test loss 4.304154, test error 52.30
# Epoch   900, train loss 0.001078, train error 0.00,  test loss 4.386282, test error 52.40
# Training model with 120 hidden variables
# Epoch     0, train loss 1.975067, train error 73.47,  test loss 1.895949, test error 72.55
# Epoch   100, train loss 0.053368, train error 0.00,  test loss 2.181792, test error 49.92
# Epoch   200, train loss 0.009670, train error 0.00,  test loss 2.813049, test error 49.62
# Epoch   300, train loss 0.004742, train error 0.00,  test loss 3.096123, test error 49.42
# Epoch   400, train loss 0.003031, train error 0.00,  test loss 3.277853, test error 49.40
# Epoch   500, train loss 0.002183, train error 0.00,  test loss 3.415166, test error 49.58
# Epoch   600, train loss 0.001685, train error 0.00,  test loss 3.521508, test error 49.55
# Epoch   700, train loss 0.001363, train error 0.00,  test loss 3.608565, test error 49.55
# Epoch   800, train loss 0.001137, train error 0.00,  test loss 3.683786, test error 49.65
# Epoch   900, train loss 0.000972, train error 0.00,  test loss 3.750330, test error 49.67
# Training model with 140 hidden variables
# Epoch     0, train loss 1.954435, train error 71.40,  test loss 1.884678, test error 71.75
# Epoch   100, train loss 0.036110, train error 0.00,  test loss 2.189816, test error 49.62
# Epoch   200, train loss 0.008031, train error 0.00,  test loss 2.683255, test error 49.90
# Epoch   300, train loss 0.004143, train error 0.00,  test loss 2.917486, test error 50.22
# Epoch   400, train loss 0.002696, train error 0.00,  test loss 3.071860, test error 50.22
# Epoch   500, train loss 0.001959, train error 0.00,  test loss 3.189283, test error 50.42
# Epoch   600, train loss 0.001522, train error 0.00,  test loss 3.279634, test error 50.33
# Epoch   700, train loss 0.001236, train error 0.00,  test loss 3.356102, test error 50.38
# Epoch   800, train loss 0.001035, train error 0.00,  test loss 3.421574, test error 50.40
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.478438, test error 50.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.945027, train error 70.93,  test loss 1.874471, test error 72.62
# Epoch   100, train loss 0.029808, train error 0.00,  test loss 2.212927, test error 49.62
# Epoch   200, train loss 0.007199, train error 0.00,  test loss 2.637633, test error 49.20
# Epoch   300, train loss 0.003790, train error 0.00,  test loss 2.852944, test error 49.12
# Epoch   400, train loss 0.002494, train error 0.00,  test loss 2.994185, test error 49.20
# Epoch   500, train loss 0.001828, train error 0.00,  test loss 3.100105, test error 49.33
# Epoch   600, train loss 0.001428, train error 0.00,  test loss 3.185657, test error 49.47
# Epoch   700, train loss 0.001163, train error 0.00,  test loss 3.255455, test error 49.35
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.316434, test error 49.47
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.368831, test error 49.53
# Training model with 180 hidden variables
# Epoch     0, train loss 1.945260, train error 70.65,  test loss 1.856020, test error 71.57
# Epoch   100, train loss 0.024960, train error 0.00,  test loss 2.036636, test error 48.35
# Epoch   200, train loss 0.006622, train error 0.00,  test loss 2.396095, test error 47.92
# Epoch   300, train loss 0.003538, train error 0.00,  test loss 2.575288, test error 48.25
# Epoch   400, train loss 0.002339, train error 0.00,  test loss 2.695524, test error 48.33
# Epoch   500, train loss 0.001719, train error 0.00,  test loss 2.785793, test error 48.42
# Epoch   600, train loss 0.001346, train error 0.00,  test loss 2.857370, test error 48.47
# Epoch   700, train loss 0.001098, train error 0.00,  test loss 2.917634, test error 48.42
# Epoch   800, train loss 0.000923, train error 0.00,  test loss 2.968463, test error 48.47
# Epoch   900, train loss 0.000793, train error 0.00,  test loss 3.013656, test error 48.47
# Training model with 200 hidden variables
# Epoch     0, train loss 1.927177, train error 71.03,  test loss 1.839530, test error 71.85
# Epoch   100, train loss 0.021247, train error 0.00,  test loss 2.021793, test error 47.92
# Epoch   200, train loss 0.006077, train error 0.00,  test loss 2.342777, test error 48.30
# Epoch   300, train loss 0.003301, train error 0.00,  test loss 2.507398, test error 48.10
# Epoch   400, train loss 0.002201, train error 0.00,  test loss 2.618033, test error 48.20
# Epoch   500, train loss 0.001627, train error 0.00,  test loss 2.700769, test error 48.15
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.768202, test error 48.17
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.823717, test error 48.33
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.871459, test error 48.35
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.913309, test error 48.30
# Training model with 250 hidden variables
# Epoch     0, train loss 1.904654, train error 68.55,  test loss 1.827711, test error 71.20
# Epoch   100, train loss 0.016833, train error 0.00,  test loss 1.947213, test error 47.90
# Epoch   200, train loss 0.005297, train error 0.00,  test loss 2.202342, test error 48.35
# Epoch   300, train loss 0.002959, train error 0.00,  test loss 2.338766, test error 48.20
# Epoch   400, train loss 0.002002, train error 0.00,  test loss 2.431913, test error 48.28
# Epoch   500, train loss 0.001492, train error 0.00,  test loss 2.502247, test error 48.15
# Epoch   600, train loss 0.001179, train error 0.00,  test loss 2.559075, test error 48.22
# Epoch   700, train loss 0.000968, train error 0.00,  test loss 2.606651, test error 48.28
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.647748, test error 48.30
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.683552, test error 48.20
# Training model with 300 hidden variables
# Epoch     0, train loss 1.890230, train error 67.97,  test loss 1.825492, test error 70.62
# Epoch   100, train loss 0.014283, train error 0.00,  test loss 1.825725, test error 45.55
# Epoch   200, train loss 0.004760, train error 0.00,  test loss 2.035316, test error 45.30
# Epoch   300, train loss 0.002700, train error 0.00,  test loss 2.149716, test error 45.50
# Epoch   400, train loss 0.001840, train error 0.00,  test loss 2.228069, test error 45.30
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.288271, test error 45.45
# Epoch   600, train loss 0.001092, train error 0.00,  test loss 2.336898, test error 45.12
# Epoch   700, train loss 0.000899, train error 0.00,  test loss 2.377544, test error 45.25
# Epoch   800, train loss 0.000761, train error 0.00,  test loss 2.412748, test error 45.12
# Epoch   900, train loss 0.000658, train error 0.00,  test loss 2.443531, test error 45.17
# Training model with 400 hidden variables
# Epoch     0, train loss 1.831295, train error 65.45,  test loss 1.773848, test error 68.03
# Epoch   100, train loss 0.011465, train error 0.00,  test loss 1.776646, test error 46.55
# Epoch   200, train loss 0.004119, train error 0.00,  test loss 1.956709, test error 46.28
# Epoch   300, train loss 0.002390, train error 0.00,  test loss 2.056205, test error 46.20
# Epoch   400, train loss 0.001647, train error 0.00,  test loss 2.125636, test error 46.28
# Epoch   500, train loss 0.001242, train error 0.00,  test loss 2.178729, test error 45.97
# Epoch   600, train loss 0.000989, train error 0.00,  test loss 2.221440, test error 46.05
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.257734, test error 46.10
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.289204, test error 46.08
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.316429, test error 46.08

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
